# %%
# hide output
# %%capture output

! pip install pdfplumber
! pip install chromadb
! pip install pymilvus
! pip install sentence-transformers
! pip install langchain
! pip install pypdf

# %%
! pip install faiss-gpu
# Out:
# Requirement already satisfied: faiss-gpu in /usr/local/lib/python3.10/dist-packages (1.7.2)

# %%
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.vectorstores import FAISS

# %% [markdown]
# # 1. Load Data

# %%
import os
from google.colab import drive
# Access drive
drive.mount('/content/drive')
path = '/content/drive/MyDrive/Capstone/'


# companies
companies = os.listdir(os.path.join(path, 'Company Reports'))
for i, comp in enumerate(companies):
    print(i, ": ", comp)


# get reports
def get_reports(comp, year:int, rep_type:int = 1):
    """
    comp:       string or index
    year:       specific year or # recent year, 0 for all
    rep_type:   report type, 1 for annual report, 2 for sustainability report, 0 for both
    ret:        list of report pathes
    """
    if type(comp) == str:
        if comp not in companies:
            print("Error: ", comp, " does not exist")
            return
    elif type(comp) == int:
        if comp not in range(len(companies)):
            print("Error: invalid index")
            return
        comp = companies[comp]
    else:
        print("Error: invalid company")
        return

    file_path = os.path.join(path, 'Company Reports', comp)
    files = os.listdir(file_path)
    files.sort(reverse=True)

    years = range(2013,2023)
    if year in range(11):
        if year:
            years = years[-year:]
    else:
        years = [year]

    if rep_type == 0:
        reps = ["", "_sus"]
    elif rep_type == 1:
        reps = [""]
    elif rep_type == 2:
        reps = ["_sus"]
    else:
        print("Error: invalid report type")
        return

    ret = []
    for year in years:
        for rep in reps:
            file = comp + '_' + str(year) + rep + '.pdf'
            if file in files:
                ret.append(file)
    return [os.path.join(file_path, file) for file in ret]
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 0 :  ExxonMobil
# 1 :  Shell plc
# 2 :  BP PLC
# 3 :  Saudi Aramco
# 4 :  Chevron
# 5 :  TotalEnergies
# 6 :  Valero Energy
# 7 :  Marathon Petroleum Corporation
# 8 :  Sinopec
# 9 :  PetroChina

# %%
file = get_reports(2, 2022, 1)

file = file[0]
file
# Out:
# '/content/drive/MyDrive/Capstone/Company Reports/BP PLC/BP PLC_2022.pdf'

# %% [markdown]
# ## 2. Load and Split

# %%
#from langchain.document_loaders import PyPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter

#loader = PyPDFLoader(file)

from langchain.document_loaders import PyPDFium2Loader

loader = PyPDFium2Loader(file)

#text_splitter = RecursiveCharacterTextSplitter(chunk_size = 1500, chunk_overlap = 0)
#all_splits = loader.load_and_split(text_splitter)


text_splitter = RecursiveCharacterTextSplitter(
    separators = ["\n\n", " ", "", "."],
    chunk_size = 1000,
    chunk_overlap = 0
)

# %%
all_splits = loader.load_and_split(text_splitter)

# %% [markdown]
# ## 3. Store in Vector database

# %%
def load(file_path):
    vs_path_faiss = os.path.join(file_path[:-4], 'faiss')
    if os.path.exists(vs_path_faiss):
        return FAISS.load_local(vs_path_faiss, embeddings)
    else:
        return FAISS.from_documents(text_splitter, embeddings)

# %%
embeddings = HuggingFaceEmbeddings()

data = text_splitter.split_documents(loader.load())

vs_faiss = FAISS.from_documents(data, embeddings)

# %% [markdown]
# ## 4. Retrive and Store Relative Contents

# %%
def print_doc(doc):
    for i, d in enumerate(doc):
        print('-'*100)
        print('|', str(i+1)+'. Page', d.metadata['page'], '|')
        print('-'*14)
        print(d.page_content)
    print('-'*100)

# %%
def store_result(doc):
  result = []
  for i, d in enumerate(doc):
    result.append(d.page_content)
  return result

# %%
question = """what is the company's financial performance?"""

#print_doc(vs_faiss.similarity_search(question))
financial = vs_faiss.similarity_search(question)

# %%
question = """what are the company's strategic initiatives?"""
strategy = vs_faiss.similarity_search(question)

# %%
question = """what is the company's market position and competition?"""

position = vs_faiss.similarity_search(question)

# %%
question = """what are the challenges the company faces?"""

challenges = vs_faiss.similarity_search(question)

# %%
question = """what is the company's future outlook?"""

future = vs_faiss.similarity_search(question)

# %%
relative_content = financial+strategy+position+challenges+future
relative_content
# Out:
# [Document(page_content='316 720 1,495 — 1,873 193 9,299 \r\nResults of operations for the year ended 31 Decembera\r\nSales and other operating revenuesd\r\nThird parties 549 — 2,101 420 2,977 3,836 — 6,551 1,588 18,022 \r\nSales between businesses 5,747 — 12,746 — 538 2,146 — 9,932 1,472 32,581 \r\n 6,296 — 14,847 420 3,515 5,982 — 16,483 3,060 50,603 \r\nExploration expenditure 11 — 144 109 172 57 — 94 (2) 585 \r\nProduction costs 498 — 2,102 83 327 592 — 723 107 4,432 \r\nProduction taxes 1 — 194 — 513 — — 1,544 73 2,325 \r\nOther costs (income)e\r\n (210) (47) 2,926 63 96 206 32 (44) 300 3,322 \r\nDepreciation, depletion and amortization 1,242 — 3,122 18 680 2,075 1 2,495 384 10,017 \r\nNet impairments and (gains) losses on sale of \r\nbusinesses and fixed assetsf\r\n (433) (901) 217 (3) 1,570 (1,189) 1,523 (341) (43) 400 \r\n 1,109 (948) 8,705 270 3,358 1,741 1,556 4,471 819 21,081 \r\nProfit (loss) before taxationg\r\n 5,187 948 6,142 150 157 4,241 (1,556) 12,012 2,241 29,522 \r\nAllocable taxes 4,443 — 1,409 50 1,814 886 (5) 6,651 842', metadata={'source': '/content/drive/MyDrive/Capstone/Company Reports/BP PLC/BP PLC_2022.pdf', 'page': 265}),
#  Document(page_content='2,778 38 676 1,331 — 2,008 180 7,301 \r\nResults of operations for the year ended 31 Decembera\r\nSales and other operating revenuese\r\nThird parties 182 — 1,700 384 1,330 2,934 2 2,469 994 9,995 \r\nSales between businesses 3,204 — 9,034 1 321 2,172 — 7,064 743 22,539 \r\n 3,386 — 10,734 385 1,651 5,106 2 9,533 1,737 32,534 \r\nExploration expenditure 76 — 78 90 29 84 — 52 15 424 \r\nProduction costs 653 — 1,953 121 371 781 — 967 121 4,967 \r\nProduction taxes (35) — 108 — 266 — — 918 51 1,308 \r\nOther costs (income)f\r\n 170 (2) 2,506 35 50 121 37 (12) 139 3,044 \r\nDepreciation, depletion and amortization 1,260 — 3,153 83 524 2,897 2 2,190 332 10,441 \r\nNet impairments and (gains) losses on sale of \r\nbusinesses and fixed\xa0assets (755) (124) (1,599) 1,075 (693) 750 — (2,762) (1) (4,109) \r\n 1,369 (126) 6,199 1,404 547 4,633 39 1,353 657 16,075 \r\nProfit (loss) before taxationg\r\n 2,017 126 4,535 (1,019) 1,104 473 (37) 8,180 1,080 16,459 \r\nAllocable taxes 302 1 1,127 171 696 363 — 3,055 404 6,119 \r\nResults', metadata={'source': '/content/drive/MyDrive/Capstone/Company Reports/BP PLC/BP PLC_2022.pdf', 'page': 267}),
#  Document(page_content='Company balance sheet \r\nAt 31\xa0December $ million\r\nNote 2022 2021\r\nNon-current assets\r\nInvestments 2 165,483 159,662 \r\nReceivables 3 772 3,234 \r\nDefined benefit pension plan surpluses 4 7,716 10,281 \r\n 173,971 173,177 \r\nCurrent assets\r\nReceivables 3 10,646 320 \r\nCash and cash equivalents 85 27 \r\n 10,731 347 \r\nTotal assets 184,702 173,524 \r\nCurrent liabilities\r\nPayables 5 5,864 9,176 \r\nNet current assets 4,867 (8,829) \r\nTotal assets less current liabilities 178,838 164,348 \r\nNon-current liabilities\r\nPayables 5 53,489 53,658 \r\nDeferred tax liabilities 6 2,692 3,575 \r\nDefined benefit pension plan deficits 4 128 237 \r\n 56,309 57,470 \r\nTotal liabilities 62,173 66,646 \r\nNet assets 122,529 106,878 \r\nCapital and reservesa\r\nProfit and loss account\r\nBrought forward 73,324 79,721 \r\nProfit (loss) for the year 30,540 (393) \r\nOther movements (15,323) (6,004) \r\n 88,541 73,324 \r\nCalled-up share capital 7 4,795 5,215 \r\nShare premium account 13,692 12,745 \r\nOther capital and reserves 15,501 15,594', metadata={'source': '/content/drive/MyDrive/Capstone/Company Reports/BP PLC/BP PLC_2022.pdf', 'page': 293}),
#  Document(page_content='3,225 138 519 1,675 1 2,503 173 8,685 \r\nResults of operations for the year ended 31 Decembera\r\nSales and other operating revenuesd\r\nThird parties 36 — 687 113 813 1,553 2 1,378 610 5,192 \r\nSales between businesses 1,759 — 6,274 — 53 1,641 — 4,805 277 14,809 \r\n 1,795 — 6,961 113 866 3,194 2 6,183 887 20,001 \r\nExploration expenditure 93 — 2,724 2,579 2,185 2,289 1 367 42 10,280 \r\nProduction costs 636 — 2,058 102 421 817 — 875 114 5,023 \r\nProduction taxes (22) — 57 — 140 — — 508 12 695 \r\nOther costs (income)e\r\n (130) 1 1,633 301 117 157 44 97 113 2,333 \r\nDepreciation, depletion and amortization 1,370 — 3,655 93 678 2,459 2 1,994 335 10,586 \r\nNet impairments and (gains) losses on sale of \r\nbusinesses and fixed assets 2,712 5 1,716 866 2,693 2,042 — 1,839 — 11,873 \r\n 4,659 6 11,843 3,941 6,234 7,764 47 5,680 616 40,790 \r\nProfit (loss) before taxationf\r\n (2,864) (6) (4,882) (3,828) (5,368) (4,570) (45) 503 271 (20,789) \r\nAllocable taxes (1,344) — (1,125) (682) (1,802) (308) 1 1,923 91', metadata={'source': '/content/drive/MyDrive/Capstone/Company Reports/BP PLC/BP PLC_2022.pdf', 'page': 269}),
#  Document(page_content='with shareholders, the workforce and other \r\nstakeholders, page 91.\r\nOur strategy and business model, pages 10-14. \r\nSustainability: ethics and compliance, page 68. \r\nSustainability: our values and code of conduct, page 66.\r\nImpact of operations on the community and the environment. Sustainability: caring for our planet, page 64. \r\nSustainability: safety, page 65.\r\nMaintaining a reputation for high standards of business conduct. Role of the board, page 87.\r\nSustainability: ethics and compliance, page 68. \r\nSustainability: our values and code of conduct, page 66.\r\nActing fairly between members of the company. How the board has engaged with shareholders, the workforce and other \r\nstakeholders, page 91.\r\nDetails of three key decisions that were taken by \r\nthe board in the past year in the context of the \r\nframework are set out on page 90.', metadata={'source': '/content/drive/MyDrive/Capstone/Company Reports/BP PLC/BP PLC_2022.pdf', 'page': 90}),
#  Document(page_content='13\r\nStrategic report\r\n See glossary on page 389 bp Annual Report and Form 20-F 2022\r\nOur business groups \r\nThis is how we are organized to deliver our strategy and grow long-term shareholder value. Our three \r\nbusiness groups are supported by four integrators to facilitate collaboration and unlock value (innovation \r\n& engineering; regions, corporates & solutions; strategy, sustainability & ventures; and trading & shipping), \r\nand three teams that serve as enablers of business delivery (finance; legal; and people & culture).\r\nDelivering value for stakeholders\r\nWe are committed to delivering long-term value for stakeholders. \r\nEmployees Government Customers \r\nand regulators\r\nInvestors and Society \r\nshareholders\r\nPartners and \r\nsuppliers\r\n~12m\r\ncustomer \r\ntouchpoints per day \r\n(2021 >12m)\r\n70%\r\nemployee \r\nengagement score \r\n– ’Pulse’ survey \r\n(2021 64%)\r\n$12.5bn\r\ncorporate income \r\ntax and production \r\ntax paid \r\n(2021 $5.4bn)\r\n$93m\r\nsupporting \r\nadditional initiatives\r\nto benefit the', metadata={'source': '/content/drive/MyDrive/Capstone/Company Reports/BP PLC/BP PLC_2022.pdf', 'page': 14}),
#  Document(page_content='5\r\nStrategic report\r\n See glossary on page 389 bp Annual Report and Form 20-F 2022\r\nIn terms of transformation, the proportion of \r\nbp’s total capital investment in what we call \r\nour\xa0transition growth engines has risen from \r\naround 3% in 2019 to around 30% in 2022. \r\nThis\xa0included: \r\n• The acquisition in 2022 of Archaea Energy, \r\na\xa0leading US producer of renewable natural \r\ngas, accelerating the growth of our \r\nbioenergy\xa0business.\r\n• The establishment of new businesses in \r\noffshore wind and hydrogen.\r\n• A tripling in the number of bp pulse EV \r\ncharge points globally, from more than \r\n7,500 in 2019, to around 22,000.\r\n• The addition of more than 750 strategic \r\nconvenience sites to our global \r\nretail\xa0network since 2019.\r\nSince 2019, bp has also reduced emissions \r\nfrom\xa0our oil and gas operations and production, \r\nfurther rationalized the portfolio and started \r\nup\xa013 major projects .\r\nThe energy trilemma\r\nRecent events have made it clear that the world \r\nwants and needs a better', metadata={'source': '/content/drive/MyDrive/Capstone/Company Reports/BP PLC/BP PLC_2022.pdf', 'page': 6}),
#  Document(page_content='December 2022, they have acted in a way that they consider, in good faith, would most likely promote the success of the company for the benefit \r\nof its members as a whole, having regard to the likely consequences of any decision in the long term and the broader interests of other stakeholders, \r\nas required by the Act.\r\n\u2002See page 89 for more information in support of this statement, including a description of the board’s activities during 2022.\r\nThe strategic report was approved by the board and signed on its behalf by Ben J.S. Mathews, company secretary, on 10 March 2023.', metadata={'source': '/content/drive/MyDrive/Capstone/Company Reports/BP PLC/BP PLC_2022.pdf', 'page': 77}),
#  Document(page_content='Cross reference to Form 20-F\r\nPage\r\nItem 1. Identity of Directors, Senior Management and Advisers n/a\r\nItem 2. Offer Statistics and Expected Timetable n/a\r\nItem 3. Key Information\r\nA. [Reserved] n/a\r\nB. Capitalization and indebtedness n/a\r\nC. Reasons for the offer and use of proceeds n/a\r\nD. Risk factors 73-75\r\nItem 4. Information on the Company\r\nA. History and development of the company 3, 31, 32-44, 206-208, 214, 220, 222-224, 358-368, 383, 387, 403\r\nB. Business overview 3, 6-9, 10-19, 32-44, 209-213, 358-373, 378\r\nC. Organizational structure 262, 403\r\nD. Property, plants and equipment 22, 41-42, 219-220, 288-290, 358-369, 374\r\nItem 4A. Unresolved Staff Comments None\r\nItem 5. Operating and Financial Review and Prospects\r\nA. Operating results 3, 6-9, 10-19, 24-25, 32-44, 122-124, 222-226, 235, 237-249, 358-368, 373-374\r\nB. Liquidity and capital resources 183-184, 220, 235-236, 237-249, 356-357\r\nC. Research and development, patent and licenses, etc. 213, 376\r\nD. Trend information 3,', metadata={'source': '/content/drive/MyDrive/Capstone/Company Reports/BP PLC/BP PLC_2022.pdf', 'page': 403}),
#  Document(page_content='people, see page 66\r\nPeople and resources\r\nThese are some of the people and resources in our business model that support how we create and \r\npreserve value for our stakeholders. Data as at 31 December 2022.\r\nFor more information on how integration \r\nis helping us deliver against our strategic \r\npriorities see pages 15, 17 and 19\r\n• Live our purpose\r\n• Play to win\r\n• Care for others\r\nStrategic \r\nfocus areas\r\nGas & low \r\ncarbon energy\r\nOil production \r\n& operations\r\nCustomers & \r\nproducts\r\nResilient \r\nhydrocarbons\r\nGas regions\r\nGas marketing and \r\ntrading\r\nOil regions Refining and oil trading\r\nBioenergy \r\nConvenience \r\nand mobility\r\nConvenience \r\nFuels\r\nEV charging \r\nCastrol, aviation, \r\nB2B/midstreamc\r\nLow carbon \r\nenergy\r\nRenewables & \r\npower \r\nHydrogen', metadata={'source': '/content/drive/MyDrive/Capstone/Company Reports/BP PLC/BP PLC_2022.pdf', 'page': 13}),
#  Document(page_content='41\r\nStrategic report\r\n See glossary on page 389 bp Annual Report and Form 20-F 2022\r\nCustomers & products\r\nCustomers & products segment comprises our customer-focused businesses, which include \r\nconvenience and retail fuels, EV charging, as well as Castrol, aviation and B2B and midstream. \r\nIt also includes our products businesses, refining & oil trading, as well as our bioenergy businesses.\r\nFinancial and operating performance\r\n$ million\r\n2022 2021 2020\r\nSales and other operating revenuesa 188,623 130,095 90,744\r\nProfit before interest and tax 10,235 5,563 622\r\nInventory holding (gains) losses« (1,366) (3,355) 2,796\r\nReplacement cost (RC) profit before interest and tax 8,869 2,208 3,418\r\nNet (favourable) adverse impact of adjusting items«b 1,920 1,044 (330)\r\nUnderlying RC profit before interest and tax« 10,789 3,252 3,088\r\nOf which:\r\ncustomers – convenience & mobility 2,966 3,052 2,883\r\nCastrol – included in customers 700 1,037 818\r\nproducts – refining & trading 7,823 200', metadata={'source': '/content/drive/MyDrive/Capstone/Company Reports/BP PLC/BP PLC_2022.pdf', 'page': 42}),
#  Document(page_content='company \r\nto an integrated energy company, we face an \r\nexpanded and rapidly evolving range of \r\ncompetitors in the sectors in which we operate. \r\nWe could be adversely affected if competitors \r\noffer superior terms for access rights or licences, \r\nor if our innovation in areas such as new low \r\ncarbon technologies, digital, customer offer, \r\nexploration, production, refining, manufacturing \r\nor renewable energy lags behind those of our \r\ncompetitors. Our performance could also be \r\nnegatively impacted if we fail to protect our \r\nintellectual property. \r\nTalent and capability: inability to attract, \r\ndevelop and retain people with necessary skills \r\nand capabilities could negatively impact delivery \r\nof our strategy. \r\nThe sectors in which we operate face increasing \r\nchallenges to attract and retain diverse, skilled \r\nand capable talent. An inability to successfully \r\nrecruit, develop and retain core skills and \r\ncapabilities and to reskill existing talent could \r\nnegatively impact', metadata={'source': '/content/drive/MyDrive/Capstone/Company Reports/BP PLC/BP PLC_2022.pdf', 'page': 75}),
#  Document(page_content='company \r\nto an integrated energy company, we face an \r\nexpanded and rapidly evolving range of \r\ncompetitors in the sectors in which we operate. \r\nWe could be adversely affected if competitors \r\noffer superior terms for access rights or licences, \r\nor if our innovation in areas such as new low \r\ncarbon technologies, digital, customer offer, \r\nexploration, production, refining, manufacturing \r\nor renewable energy lags behind those of our \r\ncompetitors. Our performance could also be \r\nnegatively impacted if we fail to protect our \r\nintellectual property. \r\nTalent and capability: inability to attract, \r\ndevelop and retain people with necessary skills \r\nand capabilities could negatively impact delivery \r\nof our strategy. \r\nThe sectors in which we operate face increasing \r\nchallenges to attract and retain diverse, skilled \r\nand capable talent. An inability to successfully \r\nrecruit, develop and retain core skills and \r\ncapabilities and to reskill existing talent could \r\nnegatively impact', metadata={'source': '/content/drive/MyDrive/Capstone/Company Reports/BP PLC/BP PLC_2022.pdf', 'page': 75}),
#  Document(page_content='associated with those opportunities could \r\nimpact our financial performance and the \r\npace of our transition to an integrated energy \r\ncompany in line with our strategy.\r\nMajor project delivery: failure to invest in \r\nthe best opportunities or deliver major projects \r\nsuccessfully could adversely affect our financial \r\nperformance.\r\nWe face challenges in developing major projects, \r\nparticularly in geographically and technically \r\nchallenging areas. Poor investment choice, \r\nefficiency or delivery, or operational challenges \r\nat any major project that underpins production \r\nor production growth, could adversely affect our \r\nfinancial performance.\r\nGeopolitical: exposure to a range of political \r\ndevelopments and consequent changes to the \r\noperating and regulatory environment could \r\ncause business disruption.\r\nWe operate and may seek new opportunities \r\nin countries, regions and cities where political, \r\neconomic and social transition may take place.\r\nPolitical instability,', metadata={'source': '/content/drive/MyDrive/Capstone/Company Reports/BP PLC/BP PLC_2022.pdf', 'page': 74}),
#  Document(page_content='ventures and associates\r\nhave not been dealt with as part of this process.\r\nA description of the principal and emerging risks \r\nfacing the company, including those that could \r\npotentially threaten its business model, future \r\nperformance, solvency or liquidity, is set out in \r\nRisk factors on page 73. During the year, the \r\nboard undertook a robust assessment of the \r\nprincipal and emerging risks facing the \r\ncompany. The principal means by which these \r\nrisks are managed or mitigated are set out on \r\npage 69. \r\nDirectors’ statements', metadata={'source': '/content/drive/MyDrive/Capstone/Company Reports/BP PLC/BP PLC_2022.pdf', 'page': 150}),
#  Document(page_content='activities could cause harm to people and \r\ndisrupt our operations.\r\nActs of terrorism, piracy, sabotage, activism and \r\nsimilar activities directed against our operations \r\nand facilities, pipelines, transportation or digital \r\ninfrastructure could cause harm to people and \r\nseverely disrupt operations. Our activities could \r\nalso be severely affected by conflict, civil strife \r\nor political unrest. \r\nProduct quality: supplying customers with \r\noff-specification products could damage our \r\nreputation, lead to regulatory action and legal \r\nliability, and impact our financial performance. \r\nFailure to meet product quality specifications \r\ncould cause harm to people and the \r\nenvironment, damage our reputation, result in \r\nregulatory action and legal liability, and impact \r\nfinancial performance. \r\nCompliance and control risks\r\nEthical misconduct and non-compliance: \r\nethical misconduct or breaches of applicable \r\nlaws by our businesses or our employees could \r\nbe damaging to our', metadata={'source': '/content/drive/MyDrive/Capstone/Company Reports/BP PLC/BP PLC_2022.pdf', 'page': 76}),
#  Document(page_content='around 4%. \r\nd By 2025.\r\nOur strategy and financial frame together underpin our investor \r\nproposition of delivering long-term value for shareholders.\r\nProfitable\r\ngrowth\r\nCommitted\r\ndistributions\r\nAs measured by adjusted EBIDA \r\nper share compound annual growth \r\nrate between the second half \r\n2019/first half 2020a\r\n and 2025\r\nROACE to >18%b\r\nDelivering\r\nlong-term\r\nshareholder\r\nvalue\r\nGrowing value and returns\r\nCompelling cash distributions\r\nSustainable\r\nvalue\r\nInvesting in transition growth \r\nengines; driving down emissions\r\n>40% capital investment in our \r\ntransition growth enginesd\r\nNet zero by 2050 or sooner \r\nacross operations, production \r\nand sales\r\nResilient dividendc\r\n, ~4% p.a. \r\ngrowth\r\n≥60% surplus cash flow as share \r\nbuybacksc', metadata={'source': '/content/drive/MyDrive/Capstone/Company Reports/BP PLC/BP PLC_2022.pdf', 'page': 26}),
#  Document(page_content='December 2022, they have acted in a way that they consider, in good faith, would most likely promote the success of the company for the benefit \r\nof its members as a whole, having regard to the likely consequences of any decision in the long term and the broader interests of other stakeholders, \r\nas required by the Act.\r\n\u2002See page 89 for more information in support of this statement, including a description of the board’s activities during 2022.\r\nThe strategic report was approved by the board and signed on its behalf by Ben J.S. Mathews, company secretary, on 10 March 2023.', metadata={'source': '/content/drive/MyDrive/Capstone/Company Reports/BP PLC/BP PLC_2022.pdf', 'page': 77}),
#  Document(page_content='Cross reference to Form 20-F\r\nPage\r\nItem 1. Identity of Directors, Senior Management and Advisers n/a\r\nItem 2. Offer Statistics and Expected Timetable n/a\r\nItem 3. Key Information\r\nA. [Reserved] n/a\r\nB. Capitalization and indebtedness n/a\r\nC. Reasons for the offer and use of proceeds n/a\r\nD. Risk factors 73-75\r\nItem 4. Information on the Company\r\nA. History and development of the company 3, 31, 32-44, 206-208, 214, 220, 222-224, 358-368, 383, 387, 403\r\nB. Business overview 3, 6-9, 10-19, 32-44, 209-213, 358-373, 378\r\nC. Organizational structure 262, 403\r\nD. Property, plants and equipment 22, 41-42, 219-220, 288-290, 358-369, 374\r\nItem 4A. Unresolved Staff Comments None\r\nItem 5. Operating and Financial Review and Prospects\r\nA. Operating results 3, 6-9, 10-19, 24-25, 32-44, 122-124, 222-226, 235, 237-249, 358-368, 373-374\r\nB. Liquidity and capital resources 183-184, 220, 235-236, 237-249, 356-357\r\nC. Research and development, patent and licenses, etc. 213, 376\r\nD. Trend information 3,', metadata={'source': '/content/drive/MyDrive/Capstone/Company Reports/BP PLC/BP PLC_2022.pdf', 'page': 403}),
#  Document(page_content='149.\r\nLonger-term viability\r\nIn accordance with provision 31 of the Code, the \r\ndirectors have assessed the prospects of the \r\ncompany over a period significantly longer than \r\n12 months. The directors believe that a viability \r\nassessment period of three years remains \r\nappropriate. This assessment is based on \r\nmanagement’s reasonable expectations of the \r\nposition and performance of the company over \r\nthis period, it’s internal detailed budgets and \r\nplanning timeframes and the targets and aims \r\nthat it has set out. \r\nOur risk management system, described in how \r\nwe manage risk on page 69, outlines our risk \r\nidentification, assessment and management \r\napproach for all risks, including our principal \r\nrisks, described on page 73. \r\nTaking into account the company’s current \r\nposition and its principal risks, the directors \r\nhave\xa0a reasonable expectation that the company \r\nwill be able to continue in operation and meet \r\nits\xa0liabilities as they fall due over the next', metadata={'source': '/content/drive/MyDrive/Capstone/Company Reports/BP PLC/BP PLC_2022.pdf', 'page': 151})]

# %% [markdown]
# ## 5. Model T-5

# %%
from langchain.llms import HuggingFacePipeline
from transformers import AutoTokenizer, pipeline, AutoModelForSeq2SeqLM

model_id = 'google/flan-t5-xxl'
tokenizer = AutoTokenizer.from_pretrained(model_id)
model = AutoModelForSeq2SeqLM.from_pretrained(model_id)

pipe = pipeline(
    "text2text-generation",
    model = model,
    tokenizer = tokenizer,
    max_length = 2000
)

llm = HuggingFacePipeline(pipeline = pipe)
# Out:
# Loading checkpoint shards:   0%|          | 0/5 [00:00<?, ?it/s]

# %% [markdown]
# ## 6. Map-reduce Chain

# %%
from langchain.chains.summarize import load_summarize_chain
from langchain.prompts import PromptTemplate

map_prompt = """Summarize the key highlights and findings of the company's annual report for 2022, including financial performance, strategic initiatives, market position, challenges faced, and future outlook, if any: /n {text} /n SUMMARY:"""
map_prompt_template = PromptTemplate(template=map_prompt, input_variables=["text"])

combine_prompt = """Generate a structured summary of the company's annual report for 2022, incorporating the information on revenue and financial performance, expenses and cost management, operations and productivity, market position and competition, strategic initiatives, challenges and risks, governance and compliance, and sustainability and social responsibility, if any: /n {text} /n SUMMARY:"""
combine_prompt_template = PromptTemplate(template=combine_prompt, input_variables=["text"])

summary_chain = load_summarize_chain(llm=llm,
                                     chain_type='map_reduce',
                                     map_prompt=map_prompt_template,
                                     combine_prompt=combine_prompt_template,
                                     verbose=True)

output = summary_chain.run(relative_content)
# Out:
# > Entering new MapReduceDocumentsChain chain...
#
#
# > Entering new LLMChain chain...
# Prompt after formatting:
# Summarize the key highlights and findings of the company's annual report for 2022, including financial performance, strategic initiatives, market position, challenges faced, and future outlook, if any: /n 316 720 1,495 — 1,873 193 9,299
# Results of operations for the year ended 31 Decembera
# Sales and other operating revenuesd
# Third parties 549 — 2,101 420 2,977 3,836 — 6,551 1,588 18,022
# Sales between businesses 5,747 — 12,746 — 538 2,146 — 9,932 1,472 32,581
#  6,296 — 14,847 420 3,515 5,982 — 16,483 3,060 50,603
# Exploration expenditure 11 — 144 109 172 57 — 94 (2) 585
# Production costs 498 — 2,102 83 327 592 — 723 107 4,432
# Production taxes 1 — 194 — 513 — — 1,544 73 2,325
# Other costs (income)e
#  (210) (47) 2,926 63 96 206 32 (44) 300 3,322
# Depreciation, depletion and amortization 1,242 — 3,122 18 680 2,075 1 2,495 384 10,017
# Net impairments and (gains) losses on sale of
# businesses and fixed assetsf
#  (433) (901) 217 (3) 1,570 (1,189) 1,523 (341) (43) 400
#  1,109 (948) 8,705 270 3,358 1,741 1,556 4,471 819 21,081
# Profit (loss) before taxationg
#  5,187 948 6,142 150 157 4,241 (1,556) 12,012 2,241 29,522
# Allocable taxes 4,443 — 1,409 50 1,814 886 (5) 6,651 842 /n SUMMARY:
# Prompt after formatting:
# Summarize the key highlights and findings of the company's annual report for 2022, including financial performance, strategic initiatives, market position, challenges faced, and future outlook, if any: /n 2,778 38 676 1,331 — 2,008 180 7,301
# Results of operations for the year ended 31 Decembera
# Sales and other operating revenuese
# Third parties 182 — 1,700 384 1,330 2,934 2 2,469 994 9,995
# Sales between businesses 3,204 — 9,034 1 321 2,172 — 7,064 743 22,539
#  3,386 — 10,734 385 1,651 5,106 2 9,533 1,737 32,534
# Exploration expenditure 76 — 78 90 29 84 — 52 15 424
# Production costs 653 — 1,953 121 371 781 — 967 121 4,967
# Production taxes (35) — 108 — 266 — — 918 51 1,308
# Other costs (income)f
#  170 (2) 2,506 35 50 121 37 (12) 139 3,044
# Depreciation, depletion and amortization 1,260 — 3,153 83 524 2,897 2 2,190 332 10,441
# Net impairments and (gains) losses on sale of
# businesses and fixed assets (755) (124) (1,599) 1,075 (693) 750 — (2,762) (1) (4,109)
#  1,369 (126) 6,199 1,404 547 4,633 39 1,353 657 16,075
# Profit (loss) before taxationg
#  2,017 126 4,535 (1,019) 1,104 473 (37) 8,180 1,080 16,459
# Allocable taxes 302 1 1,127 171 696 363 — 3,055 404 6,119
# Results /n SUMMARY:
# Prompt after formatting:
# Summarize the key highlights and findings of the company's annual report for 2022, including financial performance, strategic initiatives, market position, challenges faced, and future outlook, if any: /n Company balance sheet
# At 31 December $ million
# Note 2022 2021
# Non-current assets
# Investments 2 165,483 159,662
# Receivables 3 772 3,234
# Defined benefit pension plan surpluses 4 7,716 10,281
#  173,971 173,177
# Current assets
# Receivables 3 10,646 320
# Cash and cash equivalents 85 27
#  10,731 347
# Total assets 184,702 173,524
# Current liabilities
# Payables 5 5,864 9,176
# Net current assets 4,867 (8,829)
# Total assets less current liabilities 178,838 164,348
# Non-current liabilities
# Payables 5 53,489 53,658
# Deferred tax liabilities 6 2,692 3,575
# Defined benefit pension plan deficits 4 128 237
#  56,309 57,470
# Total liabilities 62,173 66,646
# Net assets 122,529 106,878
# Capital and reservesa
# Profit and loss account
# Brought forward 73,324 79,721
# Profit (loss) for the year 30,540 (393)
# Other movements (15,323) (6,004)
#  88,541 73,324
# Called-up share capital 7 4,795 5,215
# Share premium account 13,692 12,745
# Other capital and reserves 15,501 15,594 /n SUMMARY:
# Prompt after formatting:
# Summarize the key highlights and findings of the company's annual report for 2022, including financial performance, strategic initiatives, market position, challenges faced, and future outlook, if any: /n 3,225 138 519 1,675 1 2,503 173 8,685
# Results of operations for the year ended 31 Decembera
# Sales and other operating revenuesd
# Third parties 36 — 687 113 813 1,553 2 1,378 610 5,192
# Sales between businesses 1,759 — 6,274 — 53 1,641 — 4,805 277 14,809
#  1,795 — 6,961 113 866 3,194 2 6,183 887 20,001
# Exploration expenditure 93 — 2,724 2,579 2,185 2,289 1 367 42 10,280
# Production costs 636 — 2,058 102 421 817 — 875 114 5,023
# Production taxes (22) — 57 — 140 — — 508 12 695
# Other costs (income)e
#  (130) 1 1,633 301 117 157 44 97 113 2,333
# Depreciation, depletion and amortization 1,370 — 3,655 93 678 2,459 2 1,994 335 10,586
# Net impairments and (gains) losses on sale of
# businesses and fixed assets 2,712 5 1,716 866 2,693 2,042 — 1,839 — 11,873
#  4,659 6 11,843 3,941 6,234 7,764 47 5,680 616 40,790
# Profit (loss) before taxationf
#  (2,864) (6) (4,882) (3,828) (5,368) (4,570) (45) 503 271 (20,789)
# Allocable taxes (1,344) — (1,125) (682) (1,802) (308) 1 1,923 91 /n SUMMARY:
# Prompt after formatting:
# Summarize the key highlights and findings of the company's annual report for 2022, including financial performance, strategic initiatives, market position, challenges faced, and future outlook, if any: /n with shareholders, the workforce and other
# stakeholders, page 91.
# Our strategy and business model, pages 10-14.
# Sustainability: ethics and compliance, page 68.
# Sustainability: our values and code of conduct, page 66.
# Impact of operations on the community and the environment. Sustainability: caring for our planet, page 64.
# Sustainability: safety, page 65.
# Maintaining a reputation for high standards of business conduct. Role of the board, page 87.
# Sustainability: ethics and compliance, page 68.
# Sustainability: our values and code of conduct, page 66.
# Acting fairly between members of the company. How the board has engaged with shareholders, the workforce and other
# stakeholders, page 91.
# Details of three key decisions that were taken by
# the board in the past year in the context of the
# framework are set out on page 90. /n SUMMARY:
# Prompt after formatting:
# Summarize the key highlights and findings of the company's annual report for 2022, including financial performance, strategic initiatives, market position, challenges faced, and future outlook, if any: /n 13
# Strategic report
#  See glossary on page 389 bp Annual Report and Form 20-F 2022
# Our business groups
# This is how we are organized to deliver our strategy and grow long-term shareholder value. Our three
# business groups are supported by four integrators to facilitate collaboration and unlock value (innovation
# & engineering; regions, corporates & solutions; strategy, sustainability & ventures; and trading & shipping),
# and three teams that serve as enablers of business delivery (finance; legal; and people & culture).
# Delivering value for stakeholders
# We are committed to delivering long-term value for stakeholders.
# Employees Government Customers
# and regulators
# Investors and Society
# shareholders
# Partners and
# suppliers
# ~12m
# customer
# touchpoints per day
# (2021 >12m)
# 70%
# employee
# engagement score
# – ’Pulse’ survey
# (2021 64%)
# $12.5bn
# corporate income
# tax and production
# tax paid
# (2021 $5.4bn)
# $93m
# supporting
# additional initiatives
# to benefit the /n SUMMARY:
# Prompt after formatting:
# Summarize the key highlights and findings of the company's annual report for 2022, including financial performance, strategic initiatives, market position, challenges faced, and future outlook, if any: /n 5
# Strategic report
#  See glossary on page 389 bp Annual Report and Form 20-F 2022
# In terms of transformation, the proportion of
# bp’s total capital investment in what we call
# our transition growth engines has risen from
# around 3% in 2019 to around 30% in 2022.
# This included:
# • The acquisition in 2022 of Archaea Energy,
# a leading US producer of renewable natural
# gas, accelerating the growth of our
# bioenergy business.
# • The establishment of new businesses in
# offshore wind and hydrogen.
# • A tripling in the number of bp pulse EV
# charge points globally, from more than
# 7,500 in 2019, to around 22,000.
# • The addition of more than 750 strategic
# convenience sites to our global
# retail network since 2019.
# Since 2019, bp has also reduced emissions
# from our oil and gas operations and production,
# further rationalized the portfolio and started
# up 13 major projects .
# The energy trilemma
# Recent events have made it clear that the world
# wants and needs a better /n SUMMARY:
# Prompt after formatting:
# Summarize the key highlights and findings of the company's annual report for 2022, including financial performance, strategic initiatives, market position, challenges faced, and future outlook, if any: /n December 2022, they have acted in a way that they consider, in good faith, would most likely promote the success of the company for the benefit
# of its members as a whole, having regard to the likely consequences of any decision in the long term and the broader interests of other stakeholders,
# as required by the Act.
#  See page 89 for more information in support of this statement, including a description of the board’s activities during 2022.
# The strategic report was approved by the board and signed on its behalf by Ben J.S. Mathews, company secretary, on 10 March 2023. /n SUMMARY:
# Prompt after formatting:
# Summarize the key highlights and findings of the company's annual report for 2022, including financial performance, strategic initiatives, market position, challenges faced, and future outlook, if any: /n Cross reference to Form 20-F
# Page
# Item 1. Identity of Directors, Senior Management and Advisers n/a
# Item 2. Offer Statistics and Expected Timetable n/a
# Item 3. Key Information
# A. [Reserved] n/a
# B. Capitalization and indebtedness n/a
# C. Reasons for the offer and use of proceeds n/a
# D. Risk factors 73-75
# Item 4. Information on the Company
# A. History and development of the company 3, 31, 32-44, 206-208, 214, 220, 222-224, 358-368, 383, 387, 403
# B. Business overview 3, 6-9, 10-19, 32-44, 209-213, 358-373, 378
# C. Organizational structure 262, 403
# D. Property, plants and equipment 22, 41-42, 219-220, 288-290, 358-369, 374
# Item 4A. Unresolved Staff Comments None
# Item 5. Operating and Financial Review and Prospects
# A. Operating results 3, 6-9, 10-19, 24-25, 32-44, 122-124, 222-226, 235, 237-249, 358-368, 373-374
# B. Liquidity and capital resources 183-184, 220, 235-236, 237-249, 356-357
# C. Research and development, patent and licenses, etc. 213, 376
# D. Trend information 3, /n SUMMARY:
# Prompt after formatting:
# Summarize the key highlights and findings of the company's annual report for 2022, including financial performance, strategic initiatives, market position, challenges faced, and future outlook, if any: /n people, see page 66
# People and resources
# These are some of the people and resources in our business model that support how we create and
# preserve value for our stakeholders. Data as at 31 December 2022.
# For more information on how integration
# is helping us deliver against our strategic
# priorities see pages 15, 17 and 19
# • Live our purpose
# • Play to win
# • Care for others
# Strategic
# focus areas
# Gas & low
# carbon energy
# Oil production
# & operations
# Customers &
# products
# Resilient
# hydrocarbons
# Gas regions
# Gas marketing and
# trading
# Oil regions Refining and oil trading
# Bioenergy
# Convenience
# and mobility
# Convenience
# Fuels
# EV charging
# Castrol, aviation,
# B2B/midstreamc
# Low carbon
# energy
# Renewables &
# power
# Hydrogen /n SUMMARY:
# Prompt after formatting:
# Summarize the key highlights and findings of the company's annual report for 2022, including financial performance, strategic initiatives, market position, challenges faced, and future outlook, if any: /n 41
# Strategic report
#  See glossary on page 389 bp Annual Report and Form 20-F 2022
# Customers & products
# Customers & products segment comprises our customer-focused businesses, which include
# convenience and retail fuels, EV charging, as well as Castrol, aviation and B2B and midstream.
# It also includes our products businesses, refining & oil trading, as well as our bioenergy businesses.
# Financial and operating performance
# $ million
# 2022 2021 2020
# Sales and other operating revenuesa 188,623 130,095 90,744
# Profit before interest and tax 10,235 5,563 622
# Inventory holding (gains) losses« (1,366) (3,355) 2,796
# Replacement cost (RC) profit before interest and tax 8,869 2,208 3,418
# Net (favourable) adverse impact of adjusting items«b 1,920 1,044 (330)
# Underlying RC profit before interest and tax« 10,789 3,252 3,088
# Of which:
# customers – convenience & mobility 2,966 3,052 2,883
# Castrol – included in customers 700 1,037 818
# products – refining & trading 7,823 200 /n SUMMARY:
# Prompt after formatting:
# Summarize the key highlights and findings of the company's annual report for 2022, including financial performance, strategic initiatives, market position, challenges faced, and future outlook, if any: /n company
# to an integrated energy company, we face an
# expanded and rapidly evolving range of
# competitors in the sectors in which we operate.
# We could be adversely affected if competitors
# offer superior terms for access rights or licences,
# or if our innovation in areas such as new low
# carbon technologies, digital, customer offer,
# exploration, production, refining, manufacturing
# or renewable energy lags behind those of our
# competitors. Our performance could also be
# negatively impacted if we fail to protect our
# intellectual property.
# Talent and capability: inability to attract,
# develop and retain people with necessary skills
# and capabilities could negatively impact delivery
# of our strategy.
# The sectors in which we operate face increasing
# challenges to attract and retain diverse, skilled
# and capable talent. An inability to successfully
# recruit, develop and retain core skills and
# capabilities and to reskill existing talent could
# negatively impact /n SUMMARY:
# Prompt after formatting:
# Summarize the key highlights and findings of the company's annual report for 2022, including financial performance, strategic initiatives, market position, challenges faced, and future outlook, if any: /n company
# to an integrated energy company, we face an
# expanded and rapidly evolving range of
# competitors in the sectors in which we operate.
# We could be adversely affected if competitors
# offer superior terms for access rights or licences,
# or if our innovation in areas such as new low
# carbon technologies, digital, customer offer,
# exploration, production, refining, manufacturing
# or renewable energy lags behind those of our
# competitors. Our performance could also be
# negatively impacted if we fail to protect our
# intellectual property.
# Talent and capability: inability to attract,
# develop and retain people with necessary skills
# and capabilities could negatively impact delivery
# of our strategy.
# The sectors in which we operate face increasing
# challenges to attract and retain diverse, skilled
# and capable talent. An inability to successfully
# recruit, develop and retain core skills and
# capabilities and to reskill existing talent could
# negatively impact /n SUMMARY:
# Prompt after formatting:
# Summarize the key highlights and findings of the company's annual report for 2022, including financial performance, strategic initiatives, market position, challenges faced, and future outlook, if any: /n associated with those opportunities could
# impact our financial performance and the
# pace of our transition to an integrated energy
# company in line with our strategy.
# Major project delivery: failure to invest in
# the best opportunities or deliver major projects
# successfully could adversely affect our financial
# performance.
# We face challenges in developing major projects,
# particularly in geographically and technically
# challenging areas. Poor investment choice,
# efficiency or delivery, or operational challenges
# at any major project that underpins production
# or production growth, could adversely affect our
# financial performance.
# Geopolitical: exposure to a range of political
# developments and consequent changes to the
# operating and regulatory environment could
# cause business disruption.
# We operate and may seek new opportunities
# in countries, regions and cities where political,
# economic and social transition may take place.
# Political instability, /n SUMMARY:
# Prompt after formatting:
# Summarize the key highlights and findings of the company's annual report for 2022, including financial performance, strategic initiatives, market position, challenges faced, and future outlook, if any: /n ventures and associates
# have not been dealt with as part of this process.
# A description of the principal and emerging risks
# facing the company, including those that could
# potentially threaten its business model, future
# performance, solvency or liquidity, is set out in
# Risk factors on page 73. During the year, the
# board undertook a robust assessment of the
# principal and emerging risks facing the
# company. The principal means by which these
# risks are managed or mitigated are set out on
# page 69.
# Directors’ statements /n SUMMARY:
# Prompt after formatting:
# Summarize the key highlights and findings of the company's annual report for 2022, including financial performance, strategic initiatives, market position, challenges faced, and future outlook, if any: /n activities could cause harm to people and
# disrupt our operations.
# Acts of terrorism, piracy, sabotage, activism and
# similar activities directed against our operations
# and facilities, pipelines, transportation or digital
# infrastructure could cause harm to people and
# severely disrupt operations. Our activities could
# also be severely affected by conflict, civil strife
# or political unrest.
# Product quality: supplying customers with
# off-specification products could damage our
# reputation, lead to regulatory action and legal
# liability, and impact our financial performance.
# Failure to meet product quality specifications
# could cause harm to people and the
# environment, damage our reputation, result in
# regulatory action and legal liability, and impact
# financial performance.
# Compliance and control risks
# Ethical misconduct and non-compliance:
# ethical misconduct or breaches of applicable
# laws by our businesses or our employees could
# be damaging to our /n SUMMARY:
# Prompt after formatting:
# Summarize the key highlights and findings of the company's annual report for 2022, including financial performance, strategic initiatives, market position, challenges faced, and future outlook, if any: /n around 4%.
# d By 2025.
# Our strategy and financial frame together underpin our investor
# proposition of delivering long-term value for shareholders.
# Profitable
# growth
# Committed
# distributions
# As measured by adjusted EBIDA
# per share compound annual growth
# rate between the second half
# 2019/first half 2020a
#  and 2025
# ROACE to >18%b
# Delivering
# long-term
# shareholder
# value
# Growing value and returns
# Compelling cash distributions
# Sustainable
# value
# Investing in transition growth
# engines; driving down emissions
# >40% capital investment in our
# transition growth enginesd
# Net zero by 2050 or sooner
# across operations, production
# and sales
# Resilient dividendc
# , ~4% p.a.
# growth
# ≥60% surplus cash flow as share
# buybacksc /n SUMMARY:
# Prompt after formatting:
# Summarize the key highlights and findings of the company's annual report for 2022, including financial performance, strategic initiatives, market position, challenges faced, and future outlook, if any: /n December 2022, they have acted in a way that they consider, in good faith, would most likely promote the success of the company for the benefit
# of its members as a whole, having regard to the likely consequences of any decision in the long term and the broader interests of other stakeholders,
# as required by the Act.
#  See page 89 for more information in support of this statement, including a description of the board’s activities during 2022.
# The strategic report was approved by the board and signed on its behalf by Ben J.S. Mathews, company secretary, on 10 March 2023. /n SUMMARY:
# Prompt after formatting:
# Summarize the key highlights and findings of the company's annual report for 2022, including financial performance, strategic initiatives, market position, challenges faced, and future outlook, if any: /n Cross reference to Form 20-F
# Page
# Item 1. Identity of Directors, Senior Management and Advisers n/a
# Item 2. Offer Statistics and Expected Timetable n/a
# Item 3. Key Information
# A. [Reserved] n/a
# B. Capitalization and indebtedness n/a
# C. Reasons for the offer and use of proceeds n/a
# D. Risk factors 73-75
# Item 4. Information on the Company
# A. History and development of the company 3, 31, 32-44, 206-208, 214, 220, 222-224, 358-368, 383, 387, 403
# B. Business overview 3, 6-9, 10-19, 32-44, 209-213, 358-373, 378
# C. Organizational structure 262, 403
# D. Property, plants and equipment 22, 41-42, 219-220, 288-290, 358-369, 374
# Item 4A. Unresolved Staff Comments None
# Item 5. Operating and Financial Review and Prospects
# A. Operating results 3, 6-9, 10-19, 24-25, 32-44, 122-124, 222-226, 235, 237-249, 358-368, 373-374
# B. Liquidity and capital resources 183-184, 220, 235-236, 237-249, 356-357
# C. Research and development, patent and licenses, etc. 213, 376
# D. Trend information 3, /n SUMMARY:
# Prompt after formatting:
# Summarize the key highlights and findings of the company's annual report for 2022, including financial performance, strategic initiatives, market position, challenges faced, and future outlook, if any: /n 149.
# Longer-term viability
# In accordance with provision 31 of the Code, the
# directors have assessed the prospects of the
# company over a period significantly longer than
# 12 months. The directors believe that a viability
# assessment period of three years remains
# appropriate. This assessment is based on
# management’s reasonable expectations of the
# position and performance of the company over
# this period, it’s internal detailed budgets and
# planning timeframes and the targets and aims
# that it has set out.
# Our risk management system, described in how
# we manage risk on page 69, outlines our risk
# identification, assessment and management
# approach for all risks, including our principal
# risks, described on page 73.
# Taking into account the company’s current
# position and its principal risks, the directors
# have a reasonable expectation that the company
# will be able to continue in operation and meet
# its liabilities as they fall due over the next /n SUMMARY:
#
# > Finished chain.
# Token indices sequence length is longer than the specified maximum sequence length for this model (2161 > 1024). Running this sequence through the model will result in indexing errors
# Token indices sequence length is longer than the specified maximum sequence length for this model (2855 > 512). Running this sequence through the model will result in indexing errors
# > Entering new LLMChain chain...
# Prompt after formatting:
# Generate a structured summary of the company's annual report for 2022, incorporating the information on revenue and financial performance, expenses and cost management, operations and productivity, market position and competition, strategic initiatives, challenges and risks, governance and compliance, and sustainability and social responsibility, if any: /n The company's financial performance was impacted by the weakening of the oil price and the impact of the weaker pound.
#
# The company's sales and other operating revenues increased by 6% to $27.7 billion. The company's exploration expenditure increased by 6% to $1.8 billion. The company's production costs increased by 6% to $1.95 billion. The company's net impairments and (gains) losses on sale of businesses and fixed assets increased by 6% to $2.5 billion. The company's profit before taxation increased by 2% to $2.1 billion.
#
# The company's balance sheet shows that it has a strong financial position.
#
# The company's financial performance was impacted by the weakening of the oil price.
#
# The board has a responsibility to ensure that the company is managed in a way that is fair to all its stakeholders.
#
# bp is a leading international energy company. We are committed to delivering long-term value for our stakeholders.
#
# bp has been transforming itself from a traditional oil and gas company into a company that is a leader in the transition to a low-carbon, low-emissions future.
#
# The board of directors of the company confirms that, as at 31 December 2022, they have acted in a way that they consider, in good faith, would most likely promote the success of the company for the benefit of its members as a whole, having regard to the likely consequences of any decision in the long term and the broader interests of other stakeholders, as required by the Act. See page 89 for more information in support of this statement, including a description of the board’s activities during 2022. The strategic report was approved by the board and signed on its behalf by Ben J.S. Mathews, company secretary, on 10 March 2023.
#
# The company's annual report for 2022 includes the following:
#
# The report covers the period from 1 January 2022 to 31 December 2022.
#
# Customers & products Customers & products segment comprises our customer-focused businesses, which include convenience and retail fuels, EV charging, as well as Castrol, aviation and B2B and midstream. It also includes our products businesses, refining & oil trading, as well as our bioenergy businesses.
#
# The report covers the period from 1 January to 31 December 2022.
#
# The report covers the period from 1 January to 31 December 2022.
#
# The risks and uncertainties that could affect our business are set out in the section entitled "Risk Factors" in the report.
#
# The directors’ statements set out the directors’ assessment of the company’s performance and prospects for the year ended 31 December 2022.
#
# The report is a comprehensive report on the company's activities and performance for the year ended December 31, 2022.
#
# The Board of Directors of Engie has approved the following dividends for the year ended December 31, 2022: /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n
#
# The board of directors of the company confirms that, as at 31 December 2022, they have acted in a way that they consider, in good faith, would most likely promote the success of the company for the benefit of its members as a whole, having regard to the likely consequences of any decision in the long term and the broader interests of other stakeholders, as required by the Act. See page 89 for more information in support of this statement, including a description of the board’s activities during 2022. The strategic report was approved by the board and signed on its behalf by Ben J.S. Mathews, company secretary, on 10 March 2023.
#
# The company's annual report for 2022 includes the following:
#
# The directors have a reasonable expectation that the company will be able to continue in operation and meet its liabilities as they fall due over the next three years. /n SUMMARY:

# %% [markdown]
# ### output on file 0,2022,1

# %%
output
# Out:
# "ExxonMobil Corporation (Exxon Mobil) is a leading international energy company. Exxon Mobil is a Fortune 500 company with a market capitalization of 1 trillion. Exxon Mobil is a member of the Standard & Poor's 500 Index and the Dow Jones Industrial Average. Exxon Mobil is a Fortune 100 company and a member of the Dow Jones Sustainability Index."

# %% [markdown]
# ### output on file 2,2022,1

# %%
from langchain.chains.summarize import load_summarize_chain
from langchain.prompts import PromptTemplate

map_prompt = """Summarize the key highlights and findings of the company's annual report for 2022, including financial performance, strategic initiatives, market position, challenges faced, and future outlook, if any: /n {text} /n SUMMARY:"""
map_prompt_template = PromptTemplate(template=map_prompt, input_variables=["text"])

combine_prompt = """Generate a structured summary of the company's annual report for 2022, incorporating the information on revenue and financial performance, expenses and cost management, operations and productivity, market position and competition, strategic initiatives, challenges and risks, governance and compliance, and sustainability and social responsibility, if any: /n {text} /n SUMMARY:"""
combine_prompt_template = PromptTemplate(template=combine_prompt, input_variables=["text"])

summary_chain = load_summarize_chain(llm=llm,
                                     chain_type='map_reduce',
                                     map_prompt=map_prompt_template,
                                     combine_prompt=combine_prompt_template,
                                     verbose=True)

output = summary_chain.run(relative_content)
# Out:
# > Entering new MapReduceDocumentsChain chain...
#
#
# > Entering new LLMChain chain...
# Prompt after formatting:
# Summarize the key highlights and findings of the company's annual report for 2022, including financial performance, strategic initiatives, market position, challenges faced, and future outlook, if any: /n 316 720 1,495 — 1,873 193 9,299
# Results of operations for the year ended 31 Decembera
# Sales and other operating revenuesd
# Third parties 549 — 2,101 420 2,977 3,836 — 6,551 1,588 18,022
# Sales between businesses 5,747 — 12,746 — 538 2,146 — 9,932 1,472 32,581
#  6,296 — 14,847 420 3,515 5,982 — 16,483 3,060 50,603
# Exploration expenditure 11 — 144 109 172 57 — 94 (2) 585
# Production costs 498 — 2,102 83 327 592 — 723 107 4,432
# Production taxes 1 — 194 — 513 — — 1,544 73 2,325
# Other costs (income)e
#  (210) (47) 2,926 63 96 206 32 (44) 300 3,322
# Depreciation, depletion and amortization 1,242 — 3,122 18 680 2,075 1 2,495 384 10,017
# Net impairments and (gains) losses on sale of
# businesses and fixed assetsf
#  (433) (901) 217 (3) 1,570 (1,189) 1,523 (341) (43) 400
#  1,109 (948) 8,705 270 3,358 1,741 1,556 4,471 819 21,081
# Profit (loss) before taxationg
#  5,187 948 6,142 150 157 4,241 (1,556) 12,012 2,241 29,522
# Allocable taxes 4,443 — 1,409 50 1,814 886 (5) 6,651 842 /n SUMMARY:
# Prompt after formatting:
# Summarize the key highlights and findings of the company's annual report for 2022, including financial performance, strategic initiatives, market position, challenges faced, and future outlook, if any: /n 2,778 38 676 1,331 — 2,008 180 7,301
# Results of operations for the year ended 31 Decembera
# Sales and other operating revenuese
# Third parties 182 — 1,700 384 1,330 2,934 2 2,469 994 9,995
# Sales between businesses 3,204 — 9,034 1 321 2,172 — 7,064 743 22,539
#  3,386 — 10,734 385 1,651 5,106 2 9,533 1,737 32,534
# Exploration expenditure 76 — 78 90 29 84 — 52 15 424
# Production costs 653 — 1,953 121 371 781 — 967 121 4,967
# Production taxes (35) — 108 — 266 — — 918 51 1,308
# Other costs (income)f
#  170 (2) 2,506 35 50 121 37 (12) 139 3,044
# Depreciation, depletion and amortization 1,260 — 3,153 83 524 2,897 2 2,190 332 10,441
# Net impairments and (gains) losses on sale of
# businesses and fixed assets (755) (124) (1,599) 1,075 (693) 750 — (2,762) (1) (4,109)
#  1,369 (126) 6,199 1,404 547 4,633 39 1,353 657 16,075
# Profit (loss) before taxationg
#  2,017 126 4,535 (1,019) 1,104 473 (37) 8,180 1,080 16,459
# Allocable taxes 302 1 1,127 171 696 363 — 3,055 404 6,119
# Results /n SUMMARY:
# Prompt after formatting:
# Summarize the key highlights and findings of the company's annual report for 2022, including financial performance, strategic initiatives, market position, challenges faced, and future outlook, if any: /n Company balance sheet
# At 31 December $ million
# Note 2022 2021
# Non-current assets
# Investments 2 165,483 159,662
# Receivables 3 772 3,234
# Defined benefit pension plan surpluses 4 7,716 10,281
#  173,971 173,177
# Current assets
# Receivables 3 10,646 320
# Cash and cash equivalents 85 27
#  10,731 347
# Total assets 184,702 173,524
# Current liabilities
# Payables 5 5,864 9,176
# Net current assets 4,867 (8,829)
# Total assets less current liabilities 178,838 164,348
# Non-current liabilities
# Payables 5 53,489 53,658
# Deferred tax liabilities 6 2,692 3,575
# Defined benefit pension plan deficits 4 128 237
#  56,309 57,470
# Total liabilities 62,173 66,646
# Net assets 122,529 106,878
# Capital and reservesa
# Profit and loss account
# Brought forward 73,324 79,721
# Profit (loss) for the year 30,540 (393)
# Other movements (15,323) (6,004)
#  88,541 73,324
# Called-up share capital 7 4,795 5,215
# Share premium account 13,692 12,745
# Other capital and reserves 15,501 15,594 /n SUMMARY:
# Prompt after formatting:
# Summarize the key highlights and findings of the company's annual report for 2022, including financial performance, strategic initiatives, market position, challenges faced, and future outlook, if any: /n 3,225 138 519 1,675 1 2,503 173 8,685
# Results of operations for the year ended 31 Decembera
# Sales and other operating revenuesd
# Third parties 36 — 687 113 813 1,553 2 1,378 610 5,192
# Sales between businesses 1,759 — 6,274 — 53 1,641 — 4,805 277 14,809
#  1,795 — 6,961 113 866 3,194 2 6,183 887 20,001
# Exploration expenditure 93 — 2,724 2,579 2,185 2,289 1 367 42 10,280
# Production costs 636 — 2,058 102 421 817 — 875 114 5,023
# Production taxes (22) — 57 — 140 — — 508 12 695
# Other costs (income)e
#  (130) 1 1,633 301 117 157 44 97 113 2,333
# Depreciation, depletion and amortization 1,370 — 3,655 93 678 2,459 2 1,994 335 10,586
# Net impairments and (gains) losses on sale of
# businesses and fixed assets 2,712 5 1,716 866 2,693 2,042 — 1,839 — 11,873
#  4,659 6 11,843 3,941 6,234 7,764 47 5,680 616 40,790
# Profit (loss) before taxationf
#  (2,864) (6) (4,882) (3,828) (5,368) (4,570) (45) 503 271 (20,789)
# Allocable taxes (1,344) — (1,125) (682) (1,802) (308) 1 1,923 91 /n SUMMARY:
# Prompt after formatting:
# Summarize the key highlights and findings of the company's annual report for 2022, including financial performance, strategic initiatives, market position, challenges faced, and future outlook, if any: /n with shareholders, the workforce and other
# stakeholders, page 91.
# Our strategy and business model, pages 10-14.
# Sustainability: ethics and compliance, page 68.
# Sustainability: our values and code of conduct, page 66.
# Impact of operations on the community and the environment. Sustainability: caring for our planet, page 64.
# Sustainability: safety, page 65.
# Maintaining a reputation for high standards of business conduct. Role of the board, page 87.
# Sustainability: ethics and compliance, page 68.
# Sustainability: our values and code of conduct, page 66.
# Acting fairly between members of the company. How the board has engaged with shareholders, the workforce and other
# stakeholders, page 91.
# Details of three key decisions that were taken by
# the board in the past year in the context of the
# framework are set out on page 90. /n SUMMARY:
# Prompt after formatting:
# Summarize the key highlights and findings of the company's annual report for 2022, including financial performance, strategic initiatives, market position, challenges faced, and future outlook, if any: /n 13
# Strategic report
#  See glossary on page 389 bp Annual Report and Form 20-F 2022
# Our business groups
# This is how we are organized to deliver our strategy and grow long-term shareholder value. Our three
# business groups are supported by four integrators to facilitate collaboration and unlock value (innovation
# & engineering; regions, corporates & solutions; strategy, sustainability & ventures; and trading & shipping),
# and three teams that serve as enablers of business delivery (finance; legal; and people & culture).
# Delivering value for stakeholders
# We are committed to delivering long-term value for stakeholders.
# Employees Government Customers
# and regulators
# Investors and Society
# shareholders
# Partners and
# suppliers
# ~12m
# customer
# touchpoints per day
# (2021 >12m)
# 70%
# employee
# engagement score
# – ’Pulse’ survey
# (2021 64%)
# $12.5bn
# corporate income
# tax and production
# tax paid
# (2021 $5.4bn)
# $93m
# supporting
# additional initiatives
# to benefit the /n SUMMARY:
# Prompt after formatting:
# Summarize the key highlights and findings of the company's annual report for 2022, including financial performance, strategic initiatives, market position, challenges faced, and future outlook, if any: /n 5
# Strategic report
#  See glossary on page 389 bp Annual Report and Form 20-F 2022
# In terms of transformation, the proportion of
# bp’s total capital investment in what we call
# our transition growth engines has risen from
# around 3% in 2019 to around 30% in 2022.
# This included:
# • The acquisition in 2022 of Archaea Energy,
# a leading US producer of renewable natural
# gas, accelerating the growth of our
# bioenergy business.
# • The establishment of new businesses in
# offshore wind and hydrogen.
# • A tripling in the number of bp pulse EV
# charge points globally, from more than
# 7,500 in 2019, to around 22,000.
# • The addition of more than 750 strategic
# convenience sites to our global
# retail network since 2019.
# Since 2019, bp has also reduced emissions
# from our oil and gas operations and production,
# further rationalized the portfolio and started
# up 13 major projects .
# The energy trilemma
# Recent events have made it clear that the world
# wants and needs a better /n SUMMARY:
# Prompt after formatting:
# Summarize the key highlights and findings of the company's annual report for 2022, including financial performance, strategic initiatives, market position, challenges faced, and future outlook, if any: /n December 2022, they have acted in a way that they consider, in good faith, would most likely promote the success of the company for the benefit
# of its members as a whole, having regard to the likely consequences of any decision in the long term and the broader interests of other stakeholders,
# as required by the Act.
#  See page 89 for more information in support of this statement, including a description of the board’s activities during 2022.
# The strategic report was approved by the board and signed on its behalf by Ben J.S. Mathews, company secretary, on 10 March 2023. /n SUMMARY:
# Prompt after formatting:
# Summarize the key highlights and findings of the company's annual report for 2022, including financial performance, strategic initiatives, market position, challenges faced, and future outlook, if any: /n Cross reference to Form 20-F
# Page
# Item 1. Identity of Directors, Senior Management and Advisers n/a
# Item 2. Offer Statistics and Expected Timetable n/a
# Item 3. Key Information
# A. [Reserved] n/a
# B. Capitalization and indebtedness n/a
# C. Reasons for the offer and use of proceeds n/a
# D. Risk factors 73-75
# Item 4. Information on the Company
# A. History and development of the company 3, 31, 32-44, 206-208, 214, 220, 222-224, 358-368, 383, 387, 403
# B. Business overview 3, 6-9, 10-19, 32-44, 209-213, 358-373, 378
# C. Organizational structure 262, 403
# D. Property, plants and equipment 22, 41-42, 219-220, 288-290, 358-369, 374
# Item 4A. Unresolved Staff Comments None
# Item 5. Operating and Financial Review and Prospects
# A. Operating results 3, 6-9, 10-19, 24-25, 32-44, 122-124, 222-226, 235, 237-249, 358-368, 373-374
# B. Liquidity and capital resources 183-184, 220, 235-236, 237-249, 356-357
# C. Research and development, patent and licenses, etc. 213, 376
# D. Trend information 3, /n SUMMARY:
# Prompt after formatting:
# Summarize the key highlights and findings of the company's annual report for 2022, including financial performance, strategic initiatives, market position, challenges faced, and future outlook, if any: /n people, see page 66
# People and resources
# These are some of the people and resources in our business model that support how we create and
# preserve value for our stakeholders. Data as at 31 December 2022.
# For more information on how integration
# is helping us deliver against our strategic
# priorities see pages 15, 17 and 19
# • Live our purpose
# • Play to win
# • Care for others
# Strategic
# focus areas
# Gas & low
# carbon energy
# Oil production
# & operations
# Customers &
# products
# Resilient
# hydrocarbons
# Gas regions
# Gas marketing and
# trading
# Oil regions Refining and oil trading
# Bioenergy
# Convenience
# and mobility
# Convenience
# Fuels
# EV charging
# Castrol, aviation,
# B2B/midstreamc
# Low carbon
# energy
# Renewables &
# power
# Hydrogen /n SUMMARY:
# Prompt after formatting:
# Summarize the key highlights and findings of the company's annual report for 2022, including financial performance, strategic initiatives, market position, challenges faced, and future outlook, if any: /n 41
# Strategic report
#  See glossary on page 389 bp Annual Report and Form 20-F 2022
# Customers & products
# Customers & products segment comprises our customer-focused businesses, which include
# convenience and retail fuels, EV charging, as well as Castrol, aviation and B2B and midstream.
# It also includes our products businesses, refining & oil trading, as well as our bioenergy businesses.
# Financial and operating performance
# $ million
# 2022 2021 2020
# Sales and other operating revenuesa 188,623 130,095 90,744
# Profit before interest and tax 10,235 5,563 622
# Inventory holding (gains) losses« (1,366) (3,355) 2,796
# Replacement cost (RC) profit before interest and tax 8,869 2,208 3,418
# Net (favourable) adverse impact of adjusting items«b 1,920 1,044 (330)
# Underlying RC profit before interest and tax« 10,789 3,252 3,088
# Of which:
# customers – convenience & mobility 2,966 3,052 2,883
# Castrol – included in customers 700 1,037 818
# products – refining & trading 7,823 200 /n SUMMARY:
# Prompt after formatting:
# Summarize the key highlights and findings of the company's annual report for 2022, including financial performance, strategic initiatives, market position, challenges faced, and future outlook, if any: /n company
# to an integrated energy company, we face an
# expanded and rapidly evolving range of
# competitors in the sectors in which we operate.
# We could be adversely affected if competitors
# offer superior terms for access rights or licences,
# or if our innovation in areas such as new low
# carbon technologies, digital, customer offer,
# exploration, production, refining, manufacturing
# or renewable energy lags behind those of our
# competitors. Our performance could also be
# negatively impacted if we fail to protect our
# intellectual property.
# Talent and capability: inability to attract,
# develop and retain people with necessary skills
# and capabilities could negatively impact delivery
# of our strategy.
# The sectors in which we operate face increasing
# challenges to attract and retain diverse, skilled
# and capable talent. An inability to successfully
# recruit, develop and retain core skills and
# capabilities and to reskill existing talent could
# negatively impact /n SUMMARY:
# Prompt after formatting:
# Summarize the key highlights and findings of the company's annual report for 2022, including financial performance, strategic initiatives, market position, challenges faced, and future outlook, if any: /n company
# to an integrated energy company, we face an
# expanded and rapidly evolving range of
# competitors in the sectors in which we operate.
# We could be adversely affected if competitors
# offer superior terms for access rights or licences,
# or if our innovation in areas such as new low
# carbon technologies, digital, customer offer,
# exploration, production, refining, manufacturing
# or renewable energy lags behind those of our
# competitors. Our performance could also be
# negatively impacted if we fail to protect our
# intellectual property.
# Talent and capability: inability to attract,
# develop and retain people with necessary skills
# and capabilities could negatively impact delivery
# of our strategy.
# The sectors in which we operate face increasing
# challenges to attract and retain diverse, skilled
# and capable talent. An inability to successfully
# recruit, develop and retain core skills and
# capabilities and to reskill existing talent could
# negatively impact /n SUMMARY:
# Prompt after formatting:
# Summarize the key highlights and findings of the company's annual report for 2022, including financial performance, strategic initiatives, market position, challenges faced, and future outlook, if any: /n associated with those opportunities could
# impact our financial performance and the
# pace of our transition to an integrated energy
# company in line with our strategy.
# Major project delivery: failure to invest in
# the best opportunities or deliver major projects
# successfully could adversely affect our financial
# performance.
# We face challenges in developing major projects,
# particularly in geographically and technically
# challenging areas. Poor investment choice,
# efficiency or delivery, or operational challenges
# at any major project that underpins production
# or production growth, could adversely affect our
# financial performance.
# Geopolitical: exposure to a range of political
# developments and consequent changes to the
# operating and regulatory environment could
# cause business disruption.
# We operate and may seek new opportunities
# in countries, regions and cities where political,
# economic and social transition may take place.
# Political instability, /n SUMMARY:
# Prompt after formatting:
# Summarize the key highlights and findings of the company's annual report for 2022, including financial performance, strategic initiatives, market position, challenges faced, and future outlook, if any: /n ventures and associates
# have not been dealt with as part of this process.
# A description of the principal and emerging risks
# facing the company, including those that could
# potentially threaten its business model, future
# performance, solvency or liquidity, is set out in
# Risk factors on page 73. During the year, the
# board undertook a robust assessment of the
# principal and emerging risks facing the
# company. The principal means by which these
# risks are managed or mitigated are set out on
# page 69.
# Directors’ statements /n SUMMARY:
# Prompt after formatting:
# Summarize the key highlights and findings of the company's annual report for 2022, including financial performance, strategic initiatives, market position, challenges faced, and future outlook, if any: /n activities could cause harm to people and
# disrupt our operations.
# Acts of terrorism, piracy, sabotage, activism and
# similar activities directed against our operations
# and facilities, pipelines, transportation or digital
# infrastructure could cause harm to people and
# severely disrupt operations. Our activities could
# also be severely affected by conflict, civil strife
# or political unrest.
# Product quality: supplying customers with
# off-specification products could damage our
# reputation, lead to regulatory action and legal
# liability, and impact our financial performance.
# Failure to meet product quality specifications
# could cause harm to people and the
# environment, damage our reputation, result in
# regulatory action and legal liability, and impact
# financial performance.
# Compliance and control risks
# Ethical misconduct and non-compliance:
# ethical misconduct or breaches of applicable
# laws by our businesses or our employees could
# be damaging to our /n SUMMARY:
# Prompt after formatting:
# Summarize the key highlights and findings of the company's annual report for 2022, including financial performance, strategic initiatives, market position, challenges faced, and future outlook, if any: /n around 4%.
# d By 2025.
# Our strategy and financial frame together underpin our investor
# proposition of delivering long-term value for shareholders.
# Profitable
# growth
# Committed
# distributions
# As measured by adjusted EBIDA
# per share compound annual growth
# rate between the second half
# 2019/first half 2020a
#  and 2025
# ROACE to >18%b
# Delivering
# long-term
# shareholder
# value
# Growing value and returns
# Compelling cash distributions
# Sustainable
# value
# Investing in transition growth
# engines; driving down emissions
# >40% capital investment in our
# transition growth enginesd
# Net zero by 2050 or sooner
# across operations, production
# and sales
# Resilient dividendc
# , ~4% p.a.
# growth
# ≥60% surplus cash flow as share
# buybacksc /n SUMMARY:
# Prompt after formatting:
# Summarize the key highlights and findings of the company's annual report for 2022, including financial performance, strategic initiatives, market position, challenges faced, and future outlook, if any: /n December 2022, they have acted in a way that they consider, in good faith, would most likely promote the success of the company for the benefit
# of its members as a whole, having regard to the likely consequences of any decision in the long term and the broader interests of other stakeholders,
# as required by the Act.
#  See page 89 for more information in support of this statement, including a description of the board’s activities during 2022.
# The strategic report was approved by the board and signed on its behalf by Ben J.S. Mathews, company secretary, on 10 March 2023. /n SUMMARY:
# Prompt after formatting:
# Summarize the key highlights and findings of the company's annual report for 2022, including financial performance, strategic initiatives, market position, challenges faced, and future outlook, if any: /n Cross reference to Form 20-F
# Page
# Item 1. Identity of Directors, Senior Management and Advisers n/a
# Item 2. Offer Statistics and Expected Timetable n/a
# Item 3. Key Information
# A. [Reserved] n/a
# B. Capitalization and indebtedness n/a
# C. Reasons for the offer and use of proceeds n/a
# D. Risk factors 73-75
# Item 4. Information on the Company
# A. History and development of the company 3, 31, 32-44, 206-208, 214, 220, 222-224, 358-368, 383, 387, 403
# B. Business overview 3, 6-9, 10-19, 32-44, 209-213, 358-373, 378
# C. Organizational structure 262, 403
# D. Property, plants and equipment 22, 41-42, 219-220, 288-290, 358-369, 374
# Item 4A. Unresolved Staff Comments None
# Item 5. Operating and Financial Review and Prospects
# A. Operating results 3, 6-9, 10-19, 24-25, 32-44, 122-124, 222-226, 235, 237-249, 358-368, 373-374
# B. Liquidity and capital resources 183-184, 220, 235-236, 237-249, 356-357
# C. Research and development, patent and licenses, etc. 213, 376
# D. Trend information 3, /n SUMMARY:
# Prompt after formatting:
# Summarize the key highlights and findings of the company's annual report for 2022, including financial performance, strategic initiatives, market position, challenges faced, and future outlook, if any: /n 149.
# Longer-term viability
# In accordance with provision 31 of the Code, the
# directors have assessed the prospects of the
# company over a period significantly longer than
# 12 months. The directors believe that a viability
# assessment period of three years remains
# appropriate. This assessment is based on
# management’s reasonable expectations of the
# position and performance of the company over
# this period, it’s internal detailed budgets and
# planning timeframes and the targets and aims
# that it has set out.
# Our risk management system, described in how
# we manage risk on page 69, outlines our risk
# identification, assessment and management
# approach for all risks, including our principal
# risks, described on page 73.
# Taking into account the company’s current
# position and its principal risks, the directors
# have a reasonable expectation that the company
# will be able to continue in operation and meet
# its liabilities as they fall due over the next /n SUMMARY:
#
# > Finished chain.
# Token indices sequence length is longer than the specified maximum sequence length for this model (2161 > 1024). Running this sequence through the model will result in indexing errors
# Token indices sequence length is longer than the specified maximum sequence length for this model (2855 > 512). Running this sequence through the model will result in indexing errors
# > Entering new LLMChain chain...
# Prompt after formatting:
# Generate a structured summary of the company's annual report for 2022, incorporating the information on revenue and financial performance, expenses and cost management, operations and productivity, market position and competition, strategic initiatives, challenges and risks, governance and compliance, and sustainability and social responsibility, if any: /n The company's financial performance was impacted by the weakening of the oil price and the impact of the weaker pound.
#
# The company's sales and other operating revenues increased by 6% to $27.7 billion. The company's exploration expenditure increased by 6% to $1.8 billion. The company's production costs increased by 6% to $1.95 billion. The company's net impairments and (gains) losses on sale of businesses and fixed assets increased by 6% to $2.5 billion. The company's profit before taxation increased by 2% to $2.1 billion.
#
# The company's balance sheet shows that it has a strong financial position.
#
# The company's financial performance was impacted by the weakening of the oil price.
#
# The board has a responsibility to ensure that the company is managed in a way that is fair to all its stakeholders.
#
# bp is a leading international energy company. We are committed to delivering long-term value for our stakeholders.
#
# bp has been transforming itself from a traditional oil and gas company into a company that is a leader in the transition to a low-carbon, low-emissions future.
#
# The board of directors of the company confirms that, as at 31 December 2022, they have acted in a way that they consider, in good faith, would most likely promote the success of the company for the benefit of its members as a whole, having regard to the likely consequences of any decision in the long term and the broader interests of other stakeholders, as required by the Act. See page 89 for more information in support of this statement, including a description of the board’s activities during 2022. The strategic report was approved by the board and signed on its behalf by Ben J.S. Mathews, company secretary, on 10 March 2023.
#
# The company's annual report for 2022 includes the following:
#
# The report covers the period from 1 January 2022 to 31 December 2022.
#
# Customers & products Customers & products segment comprises our customer-focused businesses, which include convenience and retail fuels, EV charging, as well as Castrol, aviation and B2B and midstream. It also includes our products businesses, refining & oil trading, as well as our bioenergy businesses.
#
# The report covers the period from 1 January to 31 December 2022.
#
# The report covers the period from 1 January to 31 December 2022.
#
# The risks and uncertainties that could affect our business are set out in the section entitled "Risk Factors" in the report.
#
# The directors’ statements set out the directors’ assessment of the company’s performance and prospects for the year ended 31 December 2022.
#
# The report is a comprehensive report on the company's activities and performance for the year ended December 31, 2022.
#
# The Board of Directors of Engie has approved the following dividends for the year ended December 31, 2022: /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n /n
#
# The board of directors of the company confirms that, as at 31 December 2022, they have acted in a way that they consider, in good faith, would most likely promote the success of the company for the benefit of its members as a whole, having regard to the likely consequences of any decision in the long term and the broader interests of other stakeholders, as required by the Act. See page 89 for more information in support of this statement, including a description of the board’s activities during 2022. The strategic report was approved by the board and signed on its behalf by Ben J.S. Mathews, company secretary, on 10 March 2023.
#
# The company's annual report for 2022 includes the following:
#
# The directors have a reasonable expectation that the company will be able to continue in operation and meet its liabilities as they fall due over the next three years. /n SUMMARY:

# %%
output
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-61353e8b2d5a> in <cell line: 1>()
# ----> 1 output
#
# NameError: name 'output' is not defined

# %%
! pip install happytransformer
# Out:
# Collecting happytransformer
#   Downloading happytransformer-3.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: torch>=1.0 in /usr/local/lib/python3.10/dist-packages (from happytransformer) (2.1.0+cu118)
# Requirement already satisfied: tqdm>=4.43 in /usr/local/lib/python3.10/dist-packages (from happytransformer) (4.66.1)
# Collecting transformers<5.0.0,>=4.30.1 (from happytransformer)
#   Downloading transformers-4.34.1-py3-none-any.whl (7.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 33.3 MB/s eta 0:00:00
# Collecting datasets<3.0.0,>=2.13.1 (from happytransformer)
#   Downloading datasets-2.14.6-py3-none-any.whl (493 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 493.7/493.7 kB 37.7 MB/s eta 0:00:00
# Collecting sentencepiece (from happytransformer)
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 66.0 MB/s eta 0:00:00
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from happytransformer) (3.20.3)
# Collecting accelerate<1.0.0,>=0.20.1 (from happytransformer)
#   Downloading accelerate-0.24.1-py3-none-any.whl (261 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.4/261.4 kB 27.0 MB/s eta 0:00:00
# Collecting tokenizers<1.0.0,>=0.13.3 (from happytransformer)
#   Downloading tokenizers-0.14.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 67.1 MB/s eta 0:00:00
# Collecting wandb (from happytransformer)
#   Downloading wandb-0.15.12-py3-none-any.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 88.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate<1.0.0,>=0.20.1->happytransformer) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate<1.0.0,>=0.20.1->happytransformer) (23.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate<1.0.0,>=0.20.1->happytransformer) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate<1.0.0,>=0.20.1->happytransformer) (6.0.1)
# Collecting huggingface-hub (from accelerate<1.0.0,>=0.20.1->happytransformer)
#   Downloading huggingface_hub-0.18.0-py3-none-any.whl (301 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 31.2 MB/s eta 0:00:00
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets<3.0.0,>=2.13.1->happytransformer) (9.0.0)
# Collecting dill<0.3.8,>=0.3.0 (from datasets<3.0.0,>=2.13.1->happytransformer)
#   Downloading dill-0.3.7-py3-none-any.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 13.3 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets<3.0.0,>=2.13.1->happytransformer) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets<3.0.0,>=2.13.1->happytransformer) (2.31.0)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets<3.0.0,>=2.13.1->happytransformer) (3.4.1)
# Collecting multiprocess (from datasets<3.0.0,>=2.13.1->happytransformer)
#   Downloading multiprocess-0.70.15-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 17.4 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<=2023.10.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets<3.0.0,>=2.13.1->happytransformer) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets<3.0.0,>=2.13.1->happytransformer) (3.8.6)
# Collecting huggingface-hub (from accelerate<1.0.0,>=0.20.1->happytransformer)
#   Downloading huggingface_hub-0.17.3-py3-none-any.whl (295 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 33.5 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.0->happytransformer) (3.12.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.0->happytransformer) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.0->happytransformer) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.0->happytransformer) (3.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0->happytransformer) (3.1.2)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0->happytransformer) (2.1.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.30.1->happytransformer) (2023.6.3)
# Collecting safetensors>=0.3.1 (from transformers<5.0.0,>=4.30.1->happytransformer)
#   Downloading safetensors-0.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 78.1 MB/s eta 0:00:00
# Requirement already satisfied: Click!=8.0.0,>=7.1 in /usr/local/lib/python3.10/dist-packages (from wandb->happytransformer) (8.1.7)
# Collecting GitPython!=3.1.29,>=1.0.0 (from wandb->happytransformer)
#   Downloading GitPython-3.1.40-py3-none-any.whl (190 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 23.6 MB/s eta 0:00:00
# Collecting sentry-sdk>=1.0.0 (from wandb->happytransformer)
#   Downloading sentry_sdk-1.32.0-py2.py3-none-any.whl (240 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 241.0/241.0 kB 28.8 MB/s eta 0:00:00
# Collecting docker-pycreds>=0.4.0 (from wandb->happytransformer)
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Collecting pathtools (from wandb->happytransformer)
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
#   Preparing metadata (setup.py) ... done
# Collecting setproctitle (from wandb->happytransformer)
#   Downloading setproctitle-1.3.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from wandb->happytransformer) (67.7.2)
# Requirement already satisfied: appdirs>=1.4.3 in /usr/local/lib/python3.10/dist-packages (from wandb->happytransformer) (1.4.4)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from docker-pycreds>=0.4.0->wandb->happytransformer) (1.16.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets<3.0.0,>=2.13.1->happytransformer) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets<3.0.0,>=2.13.1->happytransformer) (3.3.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets<3.0.0,>=2.13.1->happytransformer) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets<3.0.0,>=2.13.1->happytransformer) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets<3.0.0,>=2.13.1->happytransformer) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets<3.0.0,>=2.13.1->happytransformer) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets<3.0.0,>=2.13.1->happytransformer) (1.3.1)
# Collecting gitdb<5,>=4.0.1 (from GitPython!=3.1.29,>=1.0.0->wandb->happytransformer)
#   Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 8.5 MB/s eta 0:00:00
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets<3.0.0,>=2.13.1->happytransformer) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets<3.0.0,>=2.13.1->happytransformer) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets<3.0.0,>=2.13.1->happytransformer) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.0->happytransformer) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets<3.0.0,>=2.13.1->happytransformer) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets<3.0.0,>=2.13.1->happytransformer) (2023.3.post1)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.0->happytransformer) (1.3.0)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb->happytransformer)
#   Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Building wheels for collected packages: pathtools
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8791 sha256=36b0eeaba3602ecf5719556b79eadeba532dff0312fb9c08ce80d4ae88dc2939
#   Stored in directory: /root/.cache/pip/wheels/e7/f3/22/152153d6eb222ee7a56ff8617d80ee5207207a8c00a7aab794
# Successfully built pathtools
# Installing collected packages: sentencepiece, pathtools, smmap, setproctitle, sentry-sdk, safetensors, docker-pycreds, dill, multiprocess, huggingface-hub, gitdb, tokenizers, GitPython, accelerate, wandb, transformers, datasets, happytransformer
# Successfully installed GitPython-3.1.40 accelerate-0.24.1 datasets-2.14.6 dill-0.3.7 docker-pycreds-0.4.0 gitdb-4.0.11 happytransformer-3.0.0 huggingface-hub-0.17.3 multiprocess-0.70.15 pathtools-0.1.2 safetensors-0.4.0 sentencepiece-0.1.99 sentry-sdk-1.32.0 setproctitle-1.3.3 smmap-5.0.1 tokenizers-0.14.1 transformers-4.34.1 wandb-0.15.12

# %%
from happytransformer import HappyTextToText, TTSettings

# %%
happy_tt = HappyTextToText("T5", "vennify/t5-base-grammar-correction")

args = TTSettings(num_beams=5, min_length=1)
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/1.42k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/892M [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/1.92k [00:00<?, ?B/s]
# Downloading spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/1.39M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/1.79k [00:00<?, ?B/s]
# This sentence has bad grammar.

# %%
output = "What we’ve achieved Increased renewable energy generating capacity to FID More clean energy What we’ve achieved Forged partnerships and collaborations to help communities benefit from the energy transition Just transition Sustainable livelihoods What we’ve achieved Confirmed that in 2022 all bp employees worldwide were paid a fair wagea Greater equity What we’ve achieved Launched a social mobility framework for action and business resource group Enhance wellbeing What we’ve achieved Provided access to health and wellbeing programmes for all employees"

# %%
# Add the prefix "grammar: " before each input
result = happy_tt.generate_text("grammar:"+output, args=args)

print(result.text) # This sentence has bad grammar.
# Out:
# What we’ve achieved Increased renewable energy generating capacity to FID More clean energy What we’ve achieved Forged partnerships and collaborations to help communities benefit from the energy transition Just transition Sustainable livelihoods What we’ve achieved Confirm
